# %%
import os
import cv2
import numpy as np
from keras.preprocessing import image
import statistics as st
import warnings
warnings.filterwarnings("ignore")
from keras.preprocessing.image import load_img, img_to_array 
from keras.models import  load_model
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# load model
model = load_model("final_model.h5")


face_haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
i=0
GR_dict={0:(0,255,0),1:(0,0,255)}

model = tf.keras.models.load_model('final_model.h5')
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

output=[]
cap = cv2.VideoCapture(0)

while (i<=50):
    ret, img = cap.read()
    #gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(img,1.05,5)

    for x,y,w,h in faces:

        face_img = img[y:y+h,x:x+w] 

        resized = cv2.resize(face_img,(224,224))
        reshaped=resized.reshape(1,224,224,3)/255
        predictions = model.predict(reshaped)

        # find max indexed array
        max_index = np.argmax(predictions[0])

        emotions = ('angry', 'disgust', 'fear', 'happy', 'sad', 'neutral', 'surprise')
        predicted_emotion = emotions[max_index]
        output.append(predicted_emotion)
            
            
            
        cv2.rectangle(img,(x,y),(x+w,y+h),GR_dict[1],2)
        cv2.rectangle(img,(x,y-40),(x+w,y),GR_dict[1],-1)
        cv2.putText(img, predicted_emotion, (x, y-10),cv2.FONT_HERSHEY_SIMPLEX,0.8,(255,255,255),2)
    i = i+1

    cv2.imshow('LIVE', img)
    key = cv2.waitKey(1)
    if key == 27: 
        cap.release()
        cv2.destroyAllWindows()
        break
print(output)
cap.release()
cv2.destroyAllWindows()
import statistics as st
final_output1 = st.mode(output)
# Out:
# 1/1 [==============================] - 8s 8s/step
# 1/1 [==============================] - 0s 372ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 125ms/step
# 1/1 [==============================] - 0s 402ms/step
# 1/1 [==============================] - 0s 223ms/step
# 1/1 [==============================] - 0s 191ms/step
# 1/1 [==============================] - 0s 206ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 194ms/step
# 1/1 [==============================] - 0s 202ms/step
# 1/1 [==============================] - 0s 173ms/step
# 1/1 [==============================] - 0s 121ms/step
# 1/1 [==============================] - 0s 160ms/step
# 1/1 [==============================] - 0s 197ms/step
# 1/1 [==============================] - 0s 277ms/step
# 1/1 [==============================] - 0s 164ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 147ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 158ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 228ms/step
# 1/1 [==============================] - 0s 265ms/step
# 1/1 [==============================] - 0s 270ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 119ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 272ms/step
# 1/1 [==============================] - 0s 143ms/step
# 1/1 [==============================] - 0s 279ms/step
# 1/1 [==============================] - 0s 399ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 167ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 235ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 148ms/step
# 1/1 [==============================] - 0s 237ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 114ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 266ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 244ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 465ms/step
# 1/1 [==============================] - 1s 634ms/step
# 1/1 [==============================] - 0s 226ms/step
# ['sad', 'sad', 'neutral', 'sad', 'neutral', 'sad', 'sad', 'sad', 'neutral', 'sad', 'sad', 'sad', 'sad', 'sad', 'sad', 'sad', 'sad', 'fear', 'sad', 'neutral', 'sad', 'sad', 'neutral', 'neutral', 'fear', 'neutral', 'fear', 'fear', 'neutral', 'neutral', 'neutral', 'fear', 'sad', 'sad', 'neutral', 'sad', 'sad', 'sad', 'sad', 'sad', 'sad', 'neutral', 'sad', 'sad', 'sad', 'sad', 'sad', 'neutral', 'sad', 'sad', 'sad', 'neutral', 'sad', 'neutral', 'sad', 'neutral', 'sad', 'neutral', 'neutral', 'sad', 'sad', 'sad', 'neutral', 'neutral', 'sad', 'neutral', 'sad', 'fear', 'sad', 'angry']

# %%
import statistics as st
final_output = st.mode(output)
final_output
# Out:
# 'sad'
